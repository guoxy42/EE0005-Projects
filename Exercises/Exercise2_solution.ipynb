# %% [markdown]
# ### Problem 1

# %%
import numpy as np
import pandas as pd
import seaborn as sb
import matplotlib.pyplot as plt

# %%
train_data = pd.read_csv("house-prices-advanced-regression-techniques/train.csv")

# %%
train_data.dtypes
# Out:
# Id                 int64
# MSSubClass         int64
# MSZoning          object
# LotFrontage      float64
# LotArea            int64
#                   ...
# MoSold             int64
# YrSold             int64
# SaleType          object
# SaleCondition     object
# SalePrice          int64
# Length: 81, dtype: object

# %%
train_data.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
# numeric_table = train_data.drop(axis=1, columns=["MSZoning", "Street", "Alley"])
numeric_table = train_data.select_dtypes(include=['int64'])
numeric_table.head()
# Out:
#    Id  MSSubClass  LotArea  OverallQual  OverallCond  YearBuilt  YearRemodAdd  \
# 0   1          60     8450            7            5       2003          2003
# 1   2          20     9600            6            8       1976          1976
# 2   3          60    11250            7            5       2001          2002
# 3   4          70     9550            7            5       1915          1970
# 4   5          60    14260            8            5       2000          2000
#
#    BsmtFinSF1  BsmtFinSF2  BsmtUnfSF  ...  WoodDeckSF  OpenPorchSF  \
# 0         706           0        150  ...           0           61
# 1         978           0        284  ...         298            0
# 2         486           0        434  ...           0           42
# 3         216           0        540  ...           0           35
# 4         655           0        490  ...         192           84
#
#    EnclosedPorch  3SsnPorch  ScreenPorch  PoolArea  MiscVal  MoSold  YrSold  \
# ...

# %% [markdown]
# ###### 就是这里，如何把int64的column挑出来
# ###### 使用select_dtypes(include=["int64"]）函数

# %% [markdown]
# ### Problem 2

# %%
numeric_table.describe()
# Out:
#                 Id   MSSubClass        LotArea  OverallQual  OverallCond  \
# count  1460.000000  1460.000000    1460.000000  1460.000000  1460.000000
# mean    730.500000    56.897260   10516.828082     6.099315     5.575342
# std     421.610009    42.300571    9981.264932     1.382997     1.112799
# min       1.000000    20.000000    1300.000000     1.000000     1.000000
# 25%     365.750000    20.000000    7553.500000     5.000000     5.000000
# 50%     730.500000    50.000000    9478.500000     6.000000     5.000000
# 75%    1095.250000    70.000000   11601.500000     7.000000     6.000000
# max    1460.000000   190.000000  215245.000000    10.000000     9.000000
#
#          YearBuilt  YearRemodAdd   BsmtFinSF1   BsmtFinSF2    BsmtUnfSF  ...  \
# count  1460.000000   1460.000000  1460.000000  1460.000000  1460.000000  ...
# mean   1971.267808   1984.865753   443.639726    46.549315   567.240411  ...
# std      30.202904     20.645407   456.098091   161.319273   441.866955  ...
# ...

# %%
sale_price = pd.DataFrame(train_data["SalePrice"])
sale_price.head()
# Out:
#    SalePrice
# 0     208500
# 1     181500
# 2     223500
# 3     140000
# 4     250000

# %%
sale_price.describe()
# Out:
#            SalePrice
# count    1460.000000
# mean   180921.195890
# std     79442.502883
# min     34900.000000
# 25%    129975.000000
# 50%    163000.000000
# 75%    214000.000000
# max    755000.000000

# %%
f, axes = plt.subplots(1, 3, figsize=(24, 4))

sb.boxplot(sale_price, orient="h", ax=axes[0] )
sb.distplot(sale_price, kde=False, ax=axes[1] )
sb.distplot(sale_price, hist=False, ax=axes[2] )

# %%
lot_area = pd.DataFrame(train_data["LotArea"])
lot_area.head()
# Out:
#    LotArea
# 0     8450
# 1     9600
# 2    11250
# 3     9550
# 4    14260

# %%
f, axes = plt.subplots(1, 3, figsize=(24, 4))

sb.boxplot(lot_area, orient="h", ax=axes[0] )
sb.distplot(lot_area, kde=False, ax=axes[1] )
sb.distplot(lot_area, hist=False, ax=axes[2] )

# %%
sb.jointplot(x=lot_area, y=sale_price, height=4)

# %%
area_and_price = pd.concat([lot_area, sale_price], axis=1)
area_and_price.corr()
# Out:
#             LotArea  SalePrice
# LotArea    1.000000   0.263843
# SalePrice  0.263843   1.000000

# %% [markdown]
# ### Problem 1，2 总结
# ###### boxplot, distplot, violinplot等函数中的第一个形参都是要画的dataframe的名字
# ###### M2 ExploratoryAnalysis.ipynb还没看，感觉是下一周的内容？？？别忘记了
